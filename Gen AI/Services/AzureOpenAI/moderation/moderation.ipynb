# %% [markdown]
# The moderations endpoint is a tool you can use to check whether text or images are potentially harmful. Once harmful content is identified, developers can take corrective action like filtering content or intervening with user accounts creating offending content.
#
# Note: *The moderation endpoint is free to use.*

# %%
# from openai import OpenAI
# client = OpenAI(
# )

# response = client.moderations.create(
#   model="omni-moderation-latest",
#   input="Are you stupid?",
# )

# print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 8
#       1 from openai import OpenAI
#       2 client = OpenAI(
#       3     # api_version="2024-08-01-preview",  # or your api version
#       4     api_key="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",
#       5     # azure_endpoint="https://barrycallebaut-openai-key1122.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview"
#       6 )
# ----> 8 response = client.moderations.create(
#       9   model="omni-moderation-latest",
#      10   input="Are you stupid?",
#      11 )
#      13 print(response)
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/resources/moderations.py:81, in Moderations.create(self, input, model, extra_headers, extra_query, extra_body, timeout)
#      47 def create(
#      48     self,
#      49     *,
#    (...)
#      57     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      58 ) -> ModerationCreateResponse:
#      59     """Classifies if text and/or image inputs are potentially harmful.
#      60
#      61     Learn more in
#    (...)
#      79       timeout: Override the client-level default timeout for this request, in seconds
#      80     """
# ---> 81     return self._post(
#      82         "/moderations",
#      83         body=maybe_transform(
#      84             {
#      85                 "input": input,
#      86                 "model": model,
#      87             },
#      88             moderation_create_params.ModerationCreateParams,
#      89         ),
#      90         options=make_request_options(
#      91             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#      92         ),
#      93         cast_to=ModerationCreateResponse,
#      94     )
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1278, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1264 def post(
#    1265     self,
#    1266     path: str,
#    (...)
#    1273     stream_cls: type[_StreamT] | None = None,
#    1274 ) -> ResponseT | _StreamT:
#    1275     opts = FinalRequestOptions.construct(
#    1276         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277     )
# -> 1278     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1044, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1042 if remaining_retries > 0 and self._should_retry(err.response):
#    1043     err.response.close()
# -> 1044     return self._retry_request(
#    1045         input_options,
#    1046         cast_to,
#    1047         retries_taken=retries_taken,
#    1048         response_headers=err.response.headers,
#    1049         stream=stream,
#    1050         stream_cls=stream_cls,
#    1051     )
#    1053 # If the response is streamed then we need to explicitly read the response
#    1054 # to completion before attempting to access the response text.
#    1055 if not err.response.is_closed:
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1093, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1089 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1090 # different thread if necessary.
#    1091 time.sleep(timeout)
# -> 1093 return self._request(
#    1094     options=options,
#    1095     cast_to=cast_to,
#    1096     retries_taken=retries_taken + 1,
#    1097     stream=stream,
#    1098     stream_cls=stream_cls,
#    1099 )
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1044, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1042 if remaining_retries > 0 and self._should_retry(err.response):
#    1043     err.response.close()
# -> 1044     return self._retry_request(
#    1045         input_options,
#    1046         cast_to,
#    1047         retries_taken=retries_taken,
#    1048         response_headers=err.response.headers,
#    1049         stream=stream,
#    1050         stream_cls=stream_cls,
#    1051     )
#    1053 # If the response is streamed then we need to explicitly read the response
#    1054 # to completion before attempting to access the response text.
#    1055 if not err.response.is_closed:
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1093, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1089 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1090 # different thread if necessary.
#    1091 time.sleep(timeout)
# -> 1093 return self._request(
#    1094     options=options,
#    1095     cast_to=cast_to,
#    1096     retries_taken=retries_taken + 1,
#    1097     stream=stream,
#    1098     stream_cls=stream_cls,
#    1099 )
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1059, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056         err.response.read()
#    1058     log.debug("Re-raising status error")
# -> 1059     raise self._make_status_error_from_response(err.response) from None
#    1061 return self._process_response(
#    1062     cast_to=cast_to,
#    1063     options=options,
#    (...)
#    1067     retries_taken=retries_taken,
#    1068 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Too Many Requests', 'type': 'invalid_request_error', 'param': None, 'code': None}}

# %%
# from openai import OpenAI
# client = OpenAI(
# )

# response = client.moderations.create(
#   model="omni-moderation-latest",
#   input=[
#       {"type": "text", "text": "Are you stupid?"},
#     #   {
#     #       "type": "image_url",
#     #       "image_url": {
#     #           "url": "https://example.com/image.png",
#     #           # can also use base64 encoded image URLs
#     #           # "url": "......"
#     #       }
#     #   },
#   ],
# )

# print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[15], line 6
#       1 from openai import OpenAI
#       2 client = OpenAI(
#       3     api_key="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",
#       4 )
# ----> 6 response = client.moderations.create(
#       7   model="omni-moderation-latest",
#       8   input=[
#       9       {"type": "text", "text": "Are you stupid?"},
#      10     #   {
#      11     #       "type": "image_url",
#      12     #       "image_url": {
#      13     #           "url": "https://example.com/image.png",
#      14     #           # can also use base64 encoded image URLs
#      15     #           # "url": "......"
#      16     #       }
#      17     #   },
#      18   ],
#      19 )
#      21 print(response)
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/resources/moderations.py:81, in Moderations.create(self, input, model, extra_headers, extra_query, extra_body, timeout)
#      47 def create(
#      48     self,
#      49     *,
#    (...)
#      57     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      58 ) -> ModerationCreateResponse:
#      59     """Classifies if text and/or image inputs are potentially harmful.
#      60
#      61     Learn more in
#    (...)
#      79       timeout: Override the client-level default timeout for this request, in seconds
#      80     """
# ---> 81     return self._post(
#      82         "/moderations",
#      83         body=maybe_transform(
#      84             {
#      85                 "input": input,
#      86                 "model": model,
#      87             },
#      88             moderation_create_params.ModerationCreateParams,
#      89         ),
#      90         options=make_request_options(
#      91             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#      92         ),
#      93         cast_to=ModerationCreateResponse,
#      94     )
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1278, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1264 def post(
#    1265     self,
#    1266     path: str,
#    (...)
#    1273     stream_cls: type[_StreamT] | None = None,
#    1274 ) -> ResponseT | _StreamT:
#    1275     opts = FinalRequestOptions.construct(
#    1276         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277     )
# -> 1278     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1044, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1042 if remaining_retries > 0 and self._should_retry(err.response):
#    1043     err.response.close()
# -> 1044     return self._retry_request(
#    1045         input_options,
#    1046         cast_to,
#    1047         retries_taken=retries_taken,
#    1048         response_headers=err.response.headers,
#    1049         stream=stream,
#    1050         stream_cls=stream_cls,
#    1051     )
#    1053 # If the response is streamed then we need to explicitly read the response
#    1054 # to completion before attempting to access the response text.
#    1055 if not err.response.is_closed:
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1093, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1089 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1090 # different thread if necessary.
#    1091 time.sleep(timeout)
# -> 1093 return self._request(
#    1094     options=options,
#    1095     cast_to=cast_to,
#    1096     retries_taken=retries_taken + 1,
#    1097     stream=stream,
#    1098     stream_cls=stream_cls,
#    1099 )
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1044, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1042 if remaining_retries > 0 and self._should_retry(err.response):
#    1043     err.response.close()
# -> 1044     return self._retry_request(
#    1045         input_options,
#    1046         cast_to,
#    1047         retries_taken=retries_taken,
#    1048         response_headers=err.response.headers,
#    1049         stream=stream,
#    1050         stream_cls=stream_cls,
#    1051     )
#    1053 # If the response is streamed then we need to explicitly read the response
#    1054 # to completion before attempting to access the response text.
#    1055 if not err.response.is_closed:
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1093, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1089 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1090 # different thread if necessary.
#    1091 time.sleep(timeout)
# -> 1093 return self._request(
#    1094     options=options,
#    1095     cast_to=cast_to,
#    1096     retries_taken=retries_taken + 1,
#    1097     stream=stream,
#    1098     stream_cls=stream_cls,
#    1099 )
#
# File ~/.pyenv/versions/3.13.0/envs/gen_AI_python3130_env/lib/python3.13/site-packages/openai/_base_client.py:1059, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056         err.response.read()
#    1058     log.debug("Re-raising status error")
# -> 1059     raise self._make_status_error_from_response(err.response) from None
#    1061 return self._process_response(
#    1062     cast_to=cast_to,
#    1063     options=options,
#    (...)
#    1067     retries_taken=retries_taken,
#    1068 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Too Many Requests', 'type': 'invalid_request_error', 'param': None, 'code': None}}
